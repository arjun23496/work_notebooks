# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import pickle as pkl
import statsmodels.api as sm
from scipy.stats import norm
from scipy.optimize import curve_fit
import pylab
import os
from kneed import DataGenerator, KneeLocator
from prediction_model import utils
from scipy import stats
import itertools
import math

from sklearn.linear_model import LogisticRegression

# %%
result_location = "/media/arjun/Shared/chaos/output_files_v2"
experiment_id = 6762730

directory = os.path.join(result_location, "rademacher_test_{}".format(experiment_id))

# %%
file_list = os.listdir(directory)
file_list = [ '.'.join(file.split('.')[:2]) for file in file_list if 'rademacher.pkl' in file ]
print(file_list)
# Out:
# ['avrora-small-HotSpot-d-l64-p4096-w100000i.analyzed-1', 'avrora-small-J9-d-l64-p4096-w100000i.analyzed-1', 'avrora-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1', 'pmd-small-HotSpot-d-l64-p4096-w100000i.analyzed-1', 'pmd-small-J9-d-l64-p4096-w100000i.analyzed-1', 'pmd-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1', 'sunflow-small-HotSpot-d-l64-p4096-w100000i.analyzed-1', 'luindex-small-HotSpot-d-l64-p4096-w100000i.analyzed-1', 'luindex-small-J9-d-l64-p4096-w100000i.analyzed-1', 'luindex-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1', 'jython-small-HotSpot-d-l64-p4096-w100000i.analyzed-1', 'sunflow-small-J9-d-l64-p4096-w100000i.analyzed-1', 'sunflow-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1', 'xalan-small-HotSpot-d-l64-p4096-w100000i.analyzed-1', 'xalan-small-J9-d-l64-p4096-w100000i.analyzed-1', 'xalan-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1', 'jython-small-J9-d-l64-p4096-w100000i.analyzed-1', 'jython-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1', 'lusearch-small-HotSpot-d-l64-p4096-w100000i.analyzed-1', 'lusearch-small-J9-d-l64-p4096-w100000i.analyzed-1', 'lusearch-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1']

# %%
rademacher_dict = {}
param_dict = {}

for program in file_list:
    print("Program: {}".format(program))
    with open(os.path.join(directory, "{}.rademacher.pkl".format(program)), 'rb') as f:
        rademacher_list = pkl.load(f)
    
    with open(os.path.join(directory, "{}.params.pkl".format(program)), 'rb') as f:
        param_list = pkl.load(f)
    
    print(param_list)
    
    with open(os.path.join(directory, "{}.result.pkl".format(program)), 'rb') as f:
        result = pkl.load(f)
    
    min_rad_list = [ np.min(rademacher_list[:val+1]) for val in range(len(rademacher_list)) ]
    
    min_rademacher = np.min(min_rad_list)
    
    for idx, val in enumerate(min_rad_list):
        if abs(val - min_rademacher) < 0.001:
            print("Min rademacher: {}, n_params: {}".format(val, param_list[idx]))
            
            program_key = '-'.join([program.split('-')[0], program.split('-')[2]])
            rademacher_dict[program_key] = val
            param_dict[program_key] = param_list[idx]
            
            break
    
    plt.ylim((0, 1))
    plt.xlabel("number of parameters")
    plt.ylabel("rademacher complexity")
    plt.plot(param_list, min_rad_list)
    plt.xlim((0, 1e5))
    plt.show()
# Out:
# Program: avrora-small-HotSpot-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.20976048920173043, n_params: 49600
# Program: avrora-small-J9-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.17728516060036126, n_params: 6940
# Program: avrora-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.3101202563139996, n_params: 49600
# Program: pmd-small-HotSpot-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.22772928886857124, n_params: 49600
# Program: pmd-small-J9-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.5485587341145042, n_params: 998320
# Program: pmd-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.46531360824438345, n_params: 99620
# Program: sunflow-small-HotSpot-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.12703612314951124, n_params: 6940
# Program: luindex-small-HotSpot-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.14941623482033567, n_params: 49600
# Program: luindex-small-J9-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.5066360446239766, n_params: 8900
# Program: luindex-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.7226469048594469, n_params: 8900
# Program: jython-small-HotSpot-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.31713018927630005, n_params: 7712
# Program: sunflow-small-J9-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.15137633364178119, n_params: 49600
# Program: sunflow-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.4631055460152036, n_params: 49600
# Program: xalan-small-HotSpot-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.17436352892565896, n_params: 49600
# Program: xalan-small-J9-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.5486597765003653, n_params: 998320
# Program: xalan-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.47735188573682596, n_params: 9712
# Program: jython-small-J9-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.3583429814091866, n_params: 99620
# Program: jython-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.5602083139658521, n_params: 998320
# Program: lusearch-small-HotSpot-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.07551151689707032, n_params: 49600
# Program: lusearch-small-J9-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.12874564064798164, n_params: 99620
# Program: lusearch-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# Min rademacher: 0.4892158194243256, n_params: 998320

# %%
fig = plt.figure(figsize=(10,5))
plt.xticks(rotation=90)
plt.plot(list(rademacher_dict.keys()), list(rademacher_dict.values()), 'bo')

# %% [markdown]
# ## Program with jvm order using Rademacher val

# %%
programs = np.unique([ val.split('-')[0] for val in list(rademacher_dict.keys()) ])
jvms = [ 'JikesRVM', 'J9', 'HotSpot' ]

for program in programs:
    vals = np.array([ rademacher_dict['-'.join([program, jvm])] for jvm in jvms ])
    
#     print(np.argsort(vals))
    print("{}, {}: {}".format(program, np.sort(vals), np.array(jvms)[np.array(np.argsort(vals))]))
# Out:
# avrora, [0.17728516 0.20976049 0.31012026]: ['J9' 'HotSpot' 'JikesRVM']
# jython, [0.31713019 0.35834298 0.56020831]: ['HotSpot' 'J9' 'JikesRVM']
# luindex, [0.14941623 0.50663604 0.7226469 ]: ['HotSpot' 'J9' 'JikesRVM']
# lusearch, [0.07551152 0.12874564 0.48921582]: ['HotSpot' 'J9' 'JikesRVM']
# pmd, [0.22772929 0.46531361 0.54855873]: ['HotSpot' 'JikesRVM' 'J9']
# sunflow, [0.12703612 0.15137633 0.46310555]: ['HotSpot' 'J9' 'JikesRVM']
# xalan, [0.17436353 0.47735189 0.54865978]: ['HotSpot' 'JikesRVM' 'J9']

# %% [markdown]
# ## Program with jvm using n_params

# %%
jvms = [ 'JikesRVM', 'J9', 'HotSpot' ]

for program in programs:
    vals = np.array([ param_dict['-'.join([program, jvm])] for jvm in jvms ])
    
#     print(np.argsort(vals))
    print("{}, {}: {}".format(program, np.sort(vals), np.array(jvms)[np.array(np.argsort(vals))]))
# Out:
# avrora, [ 6940 49600 49600]: ['J9' 'JikesRVM' 'HotSpot']
# jython, [  7712  99620 998320]: ['HotSpot' 'J9' 'JikesRVM']
# luindex, [ 8900  8900 49600]: ['JikesRVM' 'J9' 'HotSpot']
# lusearch, [ 49600  99620 998320]: ['HotSpot' 'J9' 'JikesRVM']
# pmd, [ 49600  99620 998320]: ['HotSpot' 'JikesRVM' 'J9']
# sunflow, [ 6940 49600 49600]: ['HotSpot' 'JikesRVM' 'J9']
# xalan, [  9712  49600 998320]: ['JikesRVM' 'HotSpot' 'J9']

# %% [markdown]
# ## jvm rademacher value distribution

# %%
jvms = [ 'JikesRVM', 'J9', 'HotSpot' ]

jvm_distribution = []

for jvm in jvms:
    vals = np.array([ rademacher_dict['-'.join([program, jvm])] for program in programs ])
    
    jvm_distribution.append(vals)

plt.boxplot(jvm_distribution, labels=jvms)
plt.show()

# %%
jvms = [ 'JikesRVM', 'J9', 'HotSpot' ]

for jvm in jvms:
    vals = np.array([ rademacher_dict['-'.join([program, jvm])] for program in programs ])
    
    plt.hist(vals, alpha=0.75, label=jvm)

plt.legend()
plt.show()

# %% [markdown]
# ## Correlation Anlysis

# %%
# Correlation of rademacher with program
jvms_g = [ 'HotSpot', 'JikesRVM', 'J9' ]
programs_g = [ key.split('-')[0] for key in rademacher_dict.keys() ]

max_program_corr = (-1, 0)
max_programs = None

max_jvm_corr = (-1, 0)
max_jvm = None

# %%
for jvms in itertools.permutations(jvms_g):
    jvms = np.array(jvms)

    print("Permutation: ", jvms)

    corr_rademacher = []
    corr_jvm1 = []

    for program in rademacher_dict.keys():
        corr_rademacher.append(rademacher_dict[program])
        corr_jvm1.append(program.split('-')[1])

    corr_jvm = [ np.where(np.array(jvms)==jvm)[0][0] for jvm in corr_jvm1 ]

    spearman_jvm = stats.spearmanr(np.array(corr_rademacher), np.array(corr_jvm))

    if max_jvm_corr[0] < spearman_jvm[0]:
        max_jvm_corr = spearman_jvm
        max_jvm = jvms

    plt.plot(corr_jvm, corr_rademacher, 'ro')
    plt.show()
        
    print("Correlation with jvm:", spearman_jvm)

print("Max correlation---------------")
print(max_jvm_corr)
print(max_jvm)
# Out:
# Permutation:  ['HotSpot' 'JikesRVM' 'J9']
# Correlation with jvm: SpearmanrResult(correlation=0.38525706426470974, pvalue=0.08458801685550227)
# Permutation:  ['HotSpot' 'J9' 'JikesRVM']
# Correlation with jvm: SpearmanrResult(correlation=0.6549370092500066, pvalue=0.0012727085303475634)
# Permutation:  ['JikesRVM' 'HotSpot' 'J9']
# Correlation with jvm: SpearmanrResult(correlation=-0.26967994498529685, pvalue=0.237119738409395)
# Permutation:  ['JikesRVM' 'J9' 'HotSpot']
# Correlation with jvm: SpearmanrResult(correlation=-0.6549370092500066, pvalue=0.0012727085303475634)
# Permutation:  ['J9' 'HotSpot' 'JikesRVM']
# Correlation with jvm: SpearmanrResult(correlation=0.26967994498529685, pvalue=0.237119738409395)
# Permutation:  ['J9' 'JikesRVM' 'HotSpot']
# Correlation with jvm: SpearmanrResult(correlation=-0.38525706426470974, pvalue=0.08458801685550227)
# Max correlation---------------
# SpearmanrResult(correlation=0.6549370092500066, pvalue=0.0012727085303475634)
# ['HotSpot' 'J9' 'JikesRVM']

# %% [markdown]
# ## Logistic regression

# %%
# jikes
X = np.array(list(rademacher_dict.values()))
X = X.reshape((X.shape[0], 1))

y = []
for val in rademacher_dict.keys():
    jvm_name = val.split('-')[1]
    if jvm_name == "JikesRVM":
        y.append(0)
    elif jvm_name == "J9":
        y.append(1)
    elif jvm_name == "HotSpot":
        y.append(2)
    else:
        print("Error: {}".format(jvm_name))
        
y = np.array(y)

indices = np.random.permutation(np.arange(0, X.shape[0]))

X_train = X[indices[:int(0.8*indices.shape[0])]]
y_train = y[indices[:int(0.8*indices.shape[0])]]

X_val = X[indices[int(0.8*indices.shape[0]):]]
y_val = y[indices[int(0.8*indices.shape[0]):]]

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)

clf = LogisticRegression(random_state=0).fit(X_train, y_train)

clf.score(X_val, y_val)
# Out:
# (16, 1) (16,)
# (5, 1) (5,)
# 0.4

# %%
clf.score(X, y)
# Out:
# 0.6190476190476191
