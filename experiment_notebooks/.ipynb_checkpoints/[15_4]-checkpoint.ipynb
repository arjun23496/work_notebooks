# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import pickle as pkl
import statsmodels.api as sm
from scipy.stats import norm
from scipy.optimize import curve_fit
import pylab
import os
from kneed import DataGenerator, KneeLocator
from prediction_model import utils
from scipy import stats
import itertools
import math

from sklearn.linear_model import LogisticRegression

# %%
result_location = "/media/arjun/Shared/chaos/output_files_v2"
experiment_id = 6779085

directory = os.path.join(result_location, "rademacher_test_{}".format(experiment_id))

# %%
file_list = os.listdir(directory)
file_list = [ '.'.join(file.split('.')[:2]) for file in file_list if 'rademacher.pkl' in file ]
print(file_list)
# Out:
# ['avrora-small-HotSpot-d-l64-p4096-w100000i.analyzed-1', 'avrora-small-J9-d-l64-p4096-w100000i.analyzed-1', 'pmd-small-HotSpot-d-l64-p4096-w100000i.analyzed-1', 'pmd-small-J9-d-l64-p4096-w100000i.analyzed-1', 'pmd-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1', 'sunflow-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1', 'xalan-small-HotSpot-d-l64-p4096-w100000i.analyzed-1', 'luindex-small-HotSpot-d-l64-p4096-w100000i.analyzed-1', 'luindex-small-J9-d-l64-p4096-w100000i.analyzed-1', 'luindex-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1', 'jython-small-J9-d-l64-p4096-w100000i.analyzed-1', 'jython-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1', 'sunflow-small-HotSpot-d-l64-p4096-w100000i.analyzed-1', 'sunflow-small-J9-d-l64-p4096-w100000i.analyzed-1', 'lusearch-small-HotSpot-d-l64-p4096-w100000i.analyzed-1', 'lusearch-small-J9-d-l64-p4096-w100000i.analyzed-1', 'lusearch-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1', 'avrora-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1', 'jython-small-HotSpot-d-l64-p4096-w100000i.analyzed-1', 'xalan-small-J9-d-l64-p4096-w100000i.analyzed-1', 'xalan-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1']

# %%
rademacher_dict = {}
error_bound_dict = {}
error_param_dict = {}
param_dict = {}
error_bound_list_dict={}

for program in file_list:
    print("Program: {}".format(program))
    
    with open(os.path.join(directory, "{}.pkl".format(program)), 'rb') as f:
        loss_dict = pkl.load(f)
    
    with open(os.path.join(directory, "{}.rademacher.pkl".format(program)), 'rb') as f:
        rademacher_list = pkl.load(f)
        
    with open(os.path.join(directory, "{}.errorBound.pkl".format(program)), 'rb') as f:
        error_bound_list = pkl.load(f)
    
    with open(os.path.join(directory, "{}.params.pkl".format(program)), 'rb') as f:
        param_list = pkl.load(f)
    
    with open(os.path.join(directory, "{}.result.pkl".format(program)), 'rb') as f:
        result = pkl.load(f)
    
    trace_length = 5e3
    
    print(param_list)
    print(rademacher_list)
    
    data_x = []
    data_y = []
    print("Loss dict keys: ", loss_dict.keys())
    for idx, key in enumerate(loss_dict.keys()):
        loss_array = loss_dict[key].flatten()
        data_y.extend(loss_array.tolist())
        data_x.extend([param_list[idx]]*loss_array.shape[0])
    
    min_err_bound_list = error_bound_list
#     min_err_bound_list = [ trace_length*np.min(error_bound_list[:]) for val in range(len(error_bound_list)) ]
    
    for idx in range(1, len(min_err_bound_list)):
        print("param: {}, val: {}, diff: {}".format(param_list[idx], min_err_bound_list[idx], 
                                                    (min_err_bound_list[idx-1] - min_err_bound_list[idx])))
    
    program_key = '-'.join(program.split('-')[0:3])
    rademacher_dict[program_key] = result[0]
    param_dict[program_key] = result[1]
    error_bound_dict[program_key] = np.min(min_err_bound_list)
    error_param_dict[program_key] = param_list[np.argmin(min_err_bound_list)]
    error_bound_list_dict[program_key] = min_err_bound_list
    
    print("Result Rademacher Value: {}".format(result[0]))
    print("Result Rademacher param: {}".format(result[1]))
    print("Result Error bound value: {}".format(result[2]))
    print("Result Error bound param: {}".format(result[3]))
    
#     plt.ylim((0, 1))
    plt.xlabel("number of parameters")
    plt.ylabel("Error Bound")
#     plt.plot(data_x, data_y, 'rx', alpha=0.2)
#     plt.plot(param_list, rademacher_list, label="rademacher")
    plt.plot(param_list, np.array(min_err_bound_list), label="error bound")
    
    plt.xlim((0, 1e5))
    plt.legend()
    plt.show()
# Out:
# No handles with labels found to put in legend.
# Program: avrora-small-HotSpot-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# [4.381087279080827, 4.368607294880313, 4.2640059095397955, 4.253919122018882, 4.249183554354617, 4.265784112921063, 4.245265453319299, 4.266072547671694, 4.237237177222612, 4.263399275150404, 4.249104386595551, 4.243542127612085, 4.241774048488609, 4.209891118905042]
# Loss dict keys:  dict_keys([1, 2, 6, 9, 11, 14, 17, 20, 22, 25, 27, 99, 160, 635])
# param: 712, val: 77021.84573696852, diff: 227.61750334779208
# param: 1984, val: 75302.04782065698, diff: 1719.7979163115378
# param: 2980, val: 75029.70080090855, diff: 272.34701974842756
# param: 3664, val: 75029.70080090855, diff: 0.0
# param: 4720, val: 75029.70080090855, diff: 0.0
# param: 5812, val: 74987.9889472784, diff: 41.71185363015684
# param: 6940, val: 74987.9889472784, diff: 0.0
# param: 7712, val: 74958.10996493779, diff: 29.8789823406114
# param: 8900, val: 74958.10996493779, diff: 0.0
# param: 9712, val: 74795.94568642287, diff: 162.16427851491608
# param: 49600, val: 74705.05990863711, diff: 90.88577778576291
# param: 99620, val: 74683.26584056865, diff: 21.79406806845509
# param: 998320, val: 74362.66853809892, diff: 320.5973024697305
# Result Rademacher Value: 4.209891118905042
# Result Rademacher param: 998320
# Result Error bound value: 14.872533707619786
# Result Error bound param: 998320
# No handles with labels found to put in legend.
# Program: avrora-small-J9-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# [4.360076819236875, 4.389813109495346, 4.362206177348324, 4.346913898883205, 4.304965872295279, 4.338434471642098, 4.3424008494684, 4.3297136835643535, 4.321404584106516, 4.326726786976085, 4.341782448848559, 4.319217815218864, 4.308852804774681, 4.317376636156545]
# Loss dict keys:  dict_keys([1, 2, 6, 9, 11, 14, 17, 20, 22, 25, 27, 99, 160, 635])
# param: 8900, val: 77199.41684529818, diff: 0.0
# param: 9712, val: 77199.41684529818, diff: 0.0
# param: 49600, val: 77199.41684529818, diff: 0.0
# param: 99620, val: 77199.41684529818, diff: 0.0
# param: 998320, val: 76783.3299397915, diff: 416.0869055066869
# Result Rademacher Value: 4.354976267583668
# Result Rademacher param: 5812
# Result Error bound value: 15.359493546334326
# Result Error bound param: 5812
# No handles with labels found to put in legend.
# Program: xalan-small-JikesRVM-d-l64-p4096-w100000i.analyzed-1
# [404, 712, 1984, 2980, 3664, 4720, 5812, 6940, 7712, 8900, 9712, 49600, 99620, 998320]
# [4.501238731004374, 4.490322682120176, 4.510638223811573, 4.483637845140856, 4.462163096618544, 4.473561800765541, 4.4769816512844125, 4.457156977839537, 4.4858240573276875, 4.491630000767405, 4.485416874393699, 4.47656532796238, 4.461839888235678, 4.4738133645939975]
# Loss dict keys:  dict_keys([1, 2, 6, 9, 11, 14, 17, 20, 22, 25, 27, 99, 160, 635])
# param: 712, val: 79206.23846523999, diff: 4.141395763901528
# param: 1984, val: 79206.23846523999, diff: 0.0
# param: 2980, val: 78857.74817268673, diff: 348.49029255326604
# param: 3664, val: 78857.74817268673, diff: 0.0
# param: 4720, val: 78857.74817268673, diff: 0.0
# param: 5812, val: 78857.74817268673, diff: 0.0
# param: 6940, val: 78857.74817268673, diff: 0.0
# param: 7712, val: 78857.74817268673, diff: 0.0
# param: 8900, val: 78857.74817268673, diff: 0.0
# param: 9712, val: 78784.79563998028, diff: 72.95253270644753
# param: 49600, val: 78688.74197356889, diff: 96.05366641138971
# param: 99620, val: 78661.91327736557, diff: 26.828696203316213
# param: 998320, val: 78661.91327736557, diff: 0.0
# Result Rademacher Value: 4.462163096618544
# Result Rademacher param: 3664
# Result Error bound value: 15.702296439640083
# Result Error bound param: 6940

# %%
fig = plt.figure(figsize=(10,5))
plt.xticks(rotation=90)
plt.plot(list(error_bound_dict.keys()), list(error_bound_dict.values()), 'bo')

# %%
def noise(delta):
    return np.sqrt(2*np.log(2/delta)/30)

vals = np.arange(1e-3, 1, 1e-3)

noise_vals = [ noise(val) for val in vals ]

# %%
plt.plot(vals, noise_vals)
plt.xlabel("delta")
plt.ylabel("noise")
plt.show()

# %% [markdown]
# ## Program with jvm order using Error bound

# %%
programs = np.unique([ val.split('-')[0] for val in list(error_bound_dict.keys()) ])
jvms = [ 'JikesRVM', 'J9', 'HotSpot' ]
input_types = np.unique([ val.split('-')[1] for val in list(error_bound_dict.keys()) ])

for program in programs:
    for input_type in input_types:
        vals = np.array([ error_bound_dict['-'.join([program, input_type, jvm])] for jvm in jvms ])

    #     print(np.argsort(vals))
        print("{}-{}, {}: {}".format(program, input_type, np.sort(vals), np.array(jvms)[np.array(np.argsort(vals))]))
# Out:
# avrora-small, [2.58926835 2.64138836 2.70734779]: ['HotSpot' 'J9' 'JikesRVM']
# jython-small, [2.60928448 2.66246295 2.72714086]: ['HotSpot' 'J9' 'JikesRVM']
# luindex-small, [2.58725043 2.64527258 2.73534142]: ['J9' 'HotSpot' 'JikesRVM']
# lusearch-small, [2.62164339 2.66768742 2.68808899]: ['HotSpot' 'J9' 'JikesRVM']
# pmd-small, [2.65109121 2.65666153 2.71920986]: ['HotSpot' 'J9' 'JikesRVM']
# sunflow-small, [2.62078551 2.65571781 2.67974301]: ['JikesRVM' 'HotSpot' 'J9']
# xalan-small, [2.62988474 2.68756883 2.70820735]: ['HotSpot' 'J9' 'JikesRVM']

# %%
fig = plt.figure(figsize=(10,5))
plt.xticks(rotation=90)
plt.plot(list(rademacher_dict.keys()), list(rademacher_dict.values()), 'bo')

# %% [markdown]
# ## Parameter size limit experiments
#
# This section gives the bits required if the parameter limit is fixed (takes all parameter val<limit)

# %%
for i in range(1, 1+len(error_bound_list_dict['-'.join([program, "small", "JikesRVM"])])):
    print("param_limit: {}-------------------".format(param_list[i-1]))

    for program in programs:
        for input_type in input_types:

            vals = np.array([ np.min(error_bound_list_dict['-'.join([program, input_type, jvm])][:i]) 
                             for jvm in jvms ])
            print("{}-{}, {}: {}".format(program, input_type, np.sort(vals), 
                                         np.array(jvms)[np.array(np.argsort(vals))]))
# Out:
# param_limit: 404-------------------
# avrora-small, [77069.7253302  77249.46324032 79240.02347073]: ['J9' 'HotSpot' 'JikesRVM']
# jython-small, [76291.16807367 78074.9046264  79712.61182021]: ['HotSpot' 'J9' 'JikesRVM']
# luindex-small, [75089.74286818 77845.13804536 79728.7265632 ]: ['J9' 'HotSpot' 'JikesRVM']
# lusearch-small, [77800.9411485  78384.09665567 78668.19882624]: ['HotSpot' 'JikesRVM' 'J9']
# pmd-small, [77004.46627922 77741.73265809 79334.76148206]: ['J9' 'HotSpot' 'JikesRVM']
# sunflow-small, [77762.10507838 78305.62720624 78461.85342548]: ['JikesRVM' 'HotSpot' 'J9']
# xalan-small, [77468.23166174 77582.22473288 79210.379861  ]: ['HotSpot' 'J9' 'JikesRVM']
# param_limit: 712-------------------
# avrora-small, [77021.84573697 77069.7253302  79063.41363941]: ['HotSpot' 'J9' 'JikesRVM']
# jython-small, [76291.16807367 77848.82908519 79270.13801499]: ['HotSpot' 'J9' 'JikesRVM']
# luindex-small, [74994.16157697 77845.13804536 79679.35077103]: ['J9' 'HotSpot' 'JikesRVM']
# lusearch-small, [77800.9411485  78384.09665567 78668.19882624]: ['HotSpot' 'JikesRVM' 'J9']
# pmd-small, [77004.46627922 77741.73265809 79255.65021916]: ['J9' 'HotSpot' 'JikesRVM']
# sunflow-small, [77762.10507838 78271.38922224 78436.80447777]: ['JikesRVM' 'HotSpot' 'J9']
# xalan-small, [77468.23166174 77580.41813685 79206.23846524]: ['HotSpot' 'J9' 'JikesRVM']
# param_limit: 1984-------------------
# avrora-small, [75302.04782066 76700.22628614 78637.83258443]: ['HotSpot' 'J9' 'JikesRVM']
# jython-small, [76291.16807367 77744.5943332  79270.13801499]: ['HotSpot' 'J9' 'JikesRVM']
# luindex-small, [74994.16157697 77075.08201693 79679.35077103]: ['J9' 'HotSpot' 'JikesRVM']
# lusearch-small, [76717.64771063 77527.47951887 78015.93077713]: ['HotSpot' 'J9' 'JikesRVM']
# pmd-small, [76728.75990917 77089.69263985 78970.83822626]: ['J9' 'HotSpot' 'JikesRVM']
# sunflow-small, [75897.00705161 77328.09613296 77352.10588109]: ['JikesRVM' 'J9' 'HotSpot']
# xalan-small, [76840.52535773 77278.6641067  79206.23846524]: ['HotSpot' 'J9' 'JikesRVM']
# param_limit: 2980-------------------
# avrora-small, [75029.70080091 76467.35736688 78466.78091449]: ['HotSpot' 'J9' 'JikesRVM']
# jython-small, [76291.16807367 77515.0388966  79270.13801499]: ['HotSpot' 'J9' 'JikesRVM']
# luindex-small, [74994.16157697 76734.20720147 79679.35077103]: ['J9' 'HotSpot' 'JikesRVM']
# lusearch-small, [76485.39376854 77374.74381122 78015.93077713]: ['HotSpot' 'J9' 'JikesRVM']
# pmd-small, [76626.78456209 76844.83086597 78970.83822626]: ['J9' 'HotSpot' 'JikesRVM']
# sunflow-small, [75869.58309717 77155.77902346 77187.53502563]: ['JikesRVM' 'J9' 'HotSpot']
# xalan-small, [76548.22488934 77270.09074264 78857.74817269]: ['HotSpot' 'J9' 'JikesRVM']
# param_limit: 3664-------------------
# avrora-small, [75029.70080091 76343.34719274 78457.20700913]: ['HotSpot' 'J9' 'JikesRVM']
# jython-small, [76285.0041848  77515.0388966  79164.56244242]: ['HotSpot' 'J9' 'JikesRVM']
# luindex-small, [74994.16157697 76734.20720147 79679.35077103]: ['J9' 'HotSpot' 'JikesRVM']
# lusearch-small, [76485.39376854 77030.35216206 78015.93077713]: ['HotSpot' 'J9' 'JikesRVM']
# pmd-small, [76626.78456209 76844.83086597 78970.83822626]: ['J9' 'HotSpot' 'JikesRVM']
# sunflow-small, [75869.58309717 77155.77902346 77187.53502563]: ['JikesRVM' 'J9' 'HotSpot']
# xalan-small, [76548.22488934 77199.4168453  78857.74817269]: ['HotSpot' 'J9' 'JikesRVM']
# param_limit:
: ['HotSpot' 'J9' 'JikesRVM']
# param_limit: 998320-------------------
# avrora-small, [74362.6685381  76064.62770213 78171.24373484]: ['HotSpot' 'J9' 'JikesRVM']
# jython-small, [76162.61511892 77421.87087851 79101.78122722]: ['HotSpot' 'J9' 'JikesRVM']
# luindex-small, [74776.1698051  75982.09432581 79568.96373937]: ['J9' 'HotSpot' 'JikesRVM']
# lusearch-small, [76249.93210055 76996.91911345 77618.6070596 ]: ['HotSpot' 'J9' 'JikesRVM']
# pmd-small, [76246.47432371 76578.42608629 78596.2025677 ]: ['J9' 'HotSpot' 'JikesRVM']
# sunflow-small, [75525.43068386 76896.81195271 77115.31516289]: ['JikesRVM' 'HotSpot' 'J9']
# xalan-small, [76464.90267637 76783.32993979 78661.91327737]: ['HotSpot' 'J9' 'JikesRVM']

# %% [markdown]
# This section gives the bits required if the parameter limit is fixed (takes all parameter val=limit)

# %%
for i in range(0, len(error_bound_list_dict['-'.join([program, "small", "JikesRVM"])])):
    print("param_limit: {}-------------------".format(param_list[i]))

    for program in programs:
        for input_type in input_types:
            vals = np.array([ np.min(error_bound_list_dict['-'.join([program, input_type, jvm])][i]) 
                             for jvm in jvms ])
            print("{}-{}, {}: {}".format(program, input_type, 
                                         np.sort(vals), np.array(jvms)[np.array(np.argsort(vals))]))
# Out:
# param_limit: 404-------------------
# avrora-small, [77069.7253302  77249.46324032 79240.02347073]: ['J9' 'HotSpot' 'JikesRVM']
# jython-small, [76291.16807367 78074.9046264  79712.61182021]: ['HotSpot' 'J9' 'JikesRVM']
# luindex-small, [75089.74286818 77845.13804536 79728.7265632 ]: ['J9' 'HotSpot' 'JikesRVM']
# lusearch-small, [77800.9411485  78384.09665567 78668.19882624]: ['HotSpot' 'JikesRVM' 'J9']
# pmd-small, [77004.46627922 77741.73265809 79334.76148206]: ['J9' 'HotSpot' 'JikesRVM']
# sunflow-small, [77762.10507838 78305.62720624 78461.85342548]: ['JikesRVM' 'HotSpot' 'J9']
# xalan-small, [77468.23166174 77582.22473288 79210.379861  ]: ['HotSpot' 'J9' 'JikesRVM']
# param_limit: 712-------------------
# avrora-small, [77021.84573697 77069.7253302  79063.41363941]: ['HotSpot' 'J9' 'JikesRVM']
# jython-small, [76291.16807367 77848.82908519 79270.13801499]: ['HotSpot' 'J9' 'JikesRVM']
# luindex-small, [74994.16157697 77845.13804536 79679.35077103]: ['J9' 'HotSpot' 'JikesRVM']
# lusearch-small, [77800.9411485  78384.09665567 78668.19882624]: ['HotSpot' 'JikesRVM' 'J9']
# pmd-small, [77004.46627922 77741.73265809 79255.65021916]: ['J9' 'HotSpot' 'JikesRVM']
# sunflow-small, [77762.10507838 78271.38922224 78436.80447777]: ['JikesRVM' 'HotSpot' 'J9']
# xalan-small, [77468.23166174 77580.41813685 79206.23846524]: ['HotSpot' 'J9' 'JikesRVM']
# param_limit: 1984-------------------
# avrora-small, [75302.04782066 76700.22628614 78637.83258443]: ['HotSpot' 'J9' 'JikesRVM']
# jython-small, [76291.16807367 77744.5943332  79270.13801499]: ['HotSpot' 'J9' 'JikesRVM']
# luindex-small, [74994.16157697 77075.08201693 79679.35077103]: ['J9' 'HotSpot' 'JikesRVM']
# lusearch-small, [76717.64771063 77527.47951887 78015.93077713]: ['HotSpot' 'J9' 'JikesRVM']
# pmd-small, [76728.75990917 77089.69263985 78970.83822626]: ['J9' 'HotSpot' 'JikesRVM']
# sunflow-small, [75897.00705161 77328.09613296 77352.10588109]: ['JikesRVM' 'J9' 'HotSpot']
# xalan-small, [76840.52535773 77278.6641067  79206.23846524]: ['HotSpot' 'J9' 'JikesRVM']
# param_limit: 2980-------------------
# avrora-small, [75029.70080091 76467.35736688 78466.78091449]: ['HotSpot' 'J9' 'JikesRVM']
# jython-small, [76291.16807367 77515.0388966  79270.13801499]: ['HotSpot' 'J9' 'JikesRVM']
# luindex-small, [74994.16157697 76734.20720147 79679.35077103]: ['J9' 'HotSpot' 'JikesRVM']
# lusearch-small, [76485.39376854 77374.74381122 78015.93077713]: ['HotSpot' 'J9' 'JikesRVM']
# pmd-small, [76626.78456209 76844.83086597 78970.83822626]: ['J9' 'HotSpot' 'JikesRVM']
# sunflow-small, [75869.58309717 77155.77902346 77187.53502563]: ['JikesRVM' 'J9' 'HotSpot']
# xalan-small, [76548.22488934 77270.09074264 78857.74817269]: ['HotSpot' 'J9' 'JikesRVM']
# param_limit: 3664-------------------
# avrora-small, [75029.70080091 76343.34719274 78457.20700913]: ['HotSpot' 'J9' 'JikesRVM']
# jython-small, [76285.0041848  77515.0388966  79164.56244242]: ['HotSpot' 'J9' 'JikesRVM']
# luindex-small, [74994.16157697 76734.20720147 79679.35077103]: ['J9' 'HotSpot' 'JikesRVM']
# lusearch-small, [76485.39376854 77030.35216206 78015.93077713]: ['HotSpot' 'J9' 'JikesRVM']
# pmd-small, [76626.78456209 76844.83086597 78970.83822626]: ['J9' 'HotSpot' 'JikesRVM']
# sunflow-small, [
: ['HotSpot' 'J9' 'JikesRVM']
# pmd-small, [76551.03300428 76590.25983803 78596.2025677 ]: ['J9' 'HotSpot' 'JikesRVM']
# sunflow-small, [75651.45426218 76919.83181793 77115.31516289]: ['JikesRVM' 'HotSpot' 'J9']
# xalan-small, [76464.90267637 77199.4168453  78661.91327737]: ['HotSpot' 'J9' 'JikesRVM']
# param_limit: 998320-------------------
# avrora-small, [74362.6685381  76064.62770213 78171.24373484]: ['HotSpot' 'J9' 'JikesRVM']
# jython-small, [76162.61511892 77421.87087851 79101.78122722]: ['HotSpot' 'J9' 'JikesRVM']
# luindex-small, [74776.1698051  75982.09432581 79568.96373937]: ['J9' 'HotSpot' 'JikesRVM']
# lusearch-small, [76249.93210055 76996.91911345 77618.6070596 ]: ['HotSpot' 'J9' 'JikesRVM']
# pmd-small, [76246.47432371 76578.42608629 78596.2025677 ]: ['J9' 'HotSpot' 'JikesRVM']
# sunflow-small, [75525.43068386 76896.81195271 77115.31516289]: ['JikesRVM' 'HotSpot' 'J9']
# xalan-small, [76464.90267637 76783.32993979 78661.91327737]: ['HotSpot' 'J9' 'JikesRVM']

# %% [markdown]
# ## Program with jvm order using average number of bits

# %%
programs = np.unique([ val.split('-')[0] for val in list(rademacher_dict.keys()) ])
jvms = [ 'JikesRVM', 'J9', 'HotSpot' ]

for program in programs:
    for input_type in input_types:
        vals = np.array([ rademacher_dict['-'.join([program, input_type, jvm])] for jvm in jvms ])

    #     print(np.argsort(vals))
        print("{}-{}, {}: {}".format(program, input_type, np.sort(vals), 
                                     np.array(jvms)[np.array(np.argsort(vals))]))
# Out:
# avrora-small, [4.20989112 4.30496587 4.40696638]: ['HotSpot' 'J9' 'JikesRVM']
# jython-small, [4.31236846 4.38084038 4.48249574]: ['HotSpot' 'J9' 'JikesRVM']
# luindex-small, [4.23533356 4.31581419 4.50011776]: ['J9' 'HotSpot' 'JikesRVM']
# lusearch-small, [4.31056468 4.34658152 4.38199284]: ['HotSpot' 'J9' 'JikesRVM']
# pmd-small, [4.32128217 4.34792601 4.45421191]: ['J9' 'HotSpot' 'JikesRVM']
# sunflow-small, [4.27242533 4.36317064 4.36352148]: ['JikesRVM' 'J9' 'HotSpot']
# xalan-small, [4.33042802 4.35497627 4.4621631 ]: ['HotSpot' 'J9' 'JikesRVM']

# %% [markdown]
# ## Program with jvm using n_params

# %%
jvms = [ 'JikesRVM', 'J9', 'HotSpot' ]

for program in programs:
    for input_type in input_types:
        vals = np.array([ error_param_dict['-'.join([program, input_type, jvm])] for jvm in jvms ])

    #     print(np.argsort(vals))
        print("{}-{}, {}: {}".format(program, input_type, np.sort(vals), 
                                     np.array(jvms)[np.array(np.argsort(vals))]))
# Out:
# avrora-small, [  9712  99620 998320]: ['JikesRVM' 'J9' 'HotSpot']
# jython-small, [ 6940 99620 99620]: ['J9' 'JikesRVM' 'HotSpot']
# luindex-small, [  4720  99620 998320]: ['JikesRVM' 'J9' 'HotSpot']
# lusearch-small, [  4720 998320 998320]: ['J9' 'JikesRVM' 'HotSpot']
# pmd-small, [ 99620 998320 998320]: ['JikesRVM' 'J9' 'HotSpot']
# sunflow-small, [  4720 998320 998320]: ['J9' 'JikesRVM' 'HotSpot']
# xalan-small, [  9712  99620 998320]: ['HotSpot' 'JikesRVM' 'J9']

# %% [markdown]
# ## jvm rademacher value distribution

# %%
jvms = [ 'JikesRVM', 'J9', 'HotSpot' ]

jvm_distribution = []


for jvm in jvms:
    vals = np.array([ error_bound_dict['-'.join([program, jvm])] for program in programs ])
    
    jvm_distribution.append(vals)

plt.boxplot(jvm_distribution, labels=jvms)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-149-78cb483d4b25> in <module>
#       5
#       6 for jvm in jvms:
# ----> 7     vals = np.array([ error_bound_dict['-'.join([program, jvm])] for program in programs ])
#       8
#       9     jvm_distribution.append(vals)
#
# <ipython-input-149-78cb483d4b25> in <listcomp>(.0)
#       5
#       6 for jvm in jvms:
# ----> 7     vals = np.array([ error_bound_dict['-'.join([program, jvm])] for program in programs ])
#       8
#       9     jvm_distribution.append(vals)
#
# KeyError: 'avrora-JikesRVM'

# %% [markdown]
# ## jvm param distribution

# %%
jvms = [ 'JikesRVM', 'J9', 'HotSpot' ]

jvm_distribution = []

for jvm in jvms:
    vals = np.array([ error_param_dict['-'.join([program, jvm])] for program in programs ])
    
    jvm_distribution.append(vals)

# plt.ylim((0, 2e5))
plt.boxplot(jvm_distribution, labels=jvms)
plt.show()

# %%
jvms = [ 'JikesRVM', 'J9', 'HotSpot' ]

for jvm in jvms:
    vals = np.array([ error_param_dict['-'.join([program, jvm])] for program in programs ])
    
    plt.hist(vals, alpha=0.75, label=jvm)

plt.legend()
plt.show()

# %% [markdown]
# ## Correlation Anlysis

# %%
# Correlation of rademacher with program
jvms_g = [ 'HotSpot', 'JikesRVM', 'J9' ]
programs_g = [ key.split('-')[0] for key in rademacher_dict.keys() ]

max_program_corr = (-1, 0)
max_programs = None

max_jvm_corr = (-1, 0)
max_jvm = None

# %%
for jvms in itertools.permutations(jvms_g):
    jvms = np.array(jvms)

    print("Permutation: ", jvms)

    corr_rademacher = []
    corr_jvm1 = []

    for program in rademacher_dict.keys():
        corr_rademacher.append(rademacher_dict[program])
        corr_jvm1.append(program.split('-')[1])

    corr_jvm = [ np.where(np.array(jvms)==jvm)[0][0] for jvm in corr_jvm1 ]

    spearman_jvm = stats.spearmanr(np.array(corr_rademacher), np.array(corr_jvm))

    if max_jvm_corr[0] < spearman_jvm[0]:
        max_jvm_corr = spearman_jvm
        max_jvm = jvms

    plt.plot(corr_jvm, corr_rademacher, 'ro')
    plt.show()
        
    print("Correlation with jvm:", spearman_jvm)

print("Max correlation---------------")
print(max_jvm_corr)
print(max_jvm)

# %% [markdown]
# ## Logistic regression

# %%
# jikes
X = np.array(list(error_bound_dict.values()))
X = X.reshape((X.shape[0], 1))

y = []
for val in error_bound_dict.keys():
    jvm_name = val.split('-')[1]
    if jvm_name == "JikesRVM":
        y.append(0)
    elif jvm_name == "J9":
        y.append(1)
    elif jvm_name == "HotSpot":
        y.append(2)
    else:
        print("Error: {}".format(jvm_name))
        
y = np.array(y)

indices = np.random.permutation(np.arange(0, X.shape[0]))

X_train = X[indices[:int(0.8*indices.shape[0])]]
y_train = y[indices[:int(0.8*indices.shape[0])]]

X_val = X[indices[int(0.8*indices.shape[0]):]]
y_val = y[indices[int(0.8*indices.shape[0]):]]

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)

clf = LogisticRegression(random_state=0).fit(X_train, y_train)

clf.score(X_val, y_val)

# %%
clf.score(X, y)
